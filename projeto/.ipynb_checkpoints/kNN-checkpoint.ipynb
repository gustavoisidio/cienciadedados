# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn import preprocessing

import tensorflow as tf
from keras import models
from keras import layers

import math
from sklearn.model_selection import train_test_split, StratifiedKFold
import keras
from keras.models import Sequential, Model
from keras.layers import Input, Flatten, Dense, Dropout, Convolution2D, Conv2D, MaxPooling2D, Lambda, GlobalMaxPooling2D, GlobalAveragePooling2D, BatchNormalization, Activation, AveragePooling2D, Concatenate
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.utils import np_utils

from IPython.display import Image
from IPython.core.display import HTML 

# %matplotlib inline
keras.backend.set_image_data_format('channels_last')

# %%
df = pd.read_csv("credit_preprocessed.csv")

# %%
df.shape
df = df.drop('ID', axis=1)

# %% [markdown]
# # kNN - uniform

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

knn_Acertos_Total = np.asarray([])
knn_Falhas_Total = np.asarray([])

X = df.drop('Class', axis=1).values
y = df.Class.values

for x in range(5, 400, 10):
    print("\n\nCom %d neighbors:\n" % (x))

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

    neigh = KNeighborsClassifier(n_neighbors=x, weights='uniform')
    #TREINAMENTO
    neigh.fit(X_train, y_train) 

    #TESTE

    Test = neigh.predict(X_test)
    Real = y_test

    KNN_Falhas_uniform = round((np.sum(Test != Real)*100)/(Test.size), 2)
    KNN_Acertos_uniform = round((np.sum(Test == Real)*100)/(Test.size), 2)
    
    knn_Acertos_Total = np.append(knn_Acertos_Total, KNN_Acertos_uniform)
    knn_Falhas_Total = np.append(knn_Falhas_Total, KNN_Falhas_uniform)

#     print("%s foram treinados e  %s testes foram feitos. Desses, %s tiveram resultado correto e %s falharam" % (y_train.size, Real.size, np.sum(Test == Real), np.sum(Test != Real)))
    print("Resultado: %s%% falharam e %s%% acertaram" % (KNN_Falhas_uniform, KNN_Acertos_uniform))
# Out:
# Com 5 neighbors:
#
# Resultado: 20.73% falharam e 79.27% acertaram
#
#
# Com 15 neighbors:
#
# Resultado: 19.32% falharam e 80.68% acertaram
#
#
# Com 25 neighbors:
#
# Resultado: 18.18% falharam e 81.82% acertaram
#
#
# Com 35 neighbors:
#
# Resultado: 18.59% falharam e 81.41% acertaram
#
#
# Com 45 neighbors:
#
# Resultado: 18.08% falharam e 81.92% acertaram
#
#
# Com 55 neighbors:
#
# Resultado: 19.01% falharam e 80.99% acertaram
#
#
# Com 65 neighbors:
#
# Resultado: 18.86% falharam e 81.14% acertaram
#
#
# Com 75 neighbors:
#
# Resultado: 19.0% falharam e 81.0% acertaram
#
#
# Com 85 neighbors:
#
# Resultado: 19.36% falharam e 80.64% acertaram
#
#
# Com 95 neighbors:
#
# Resultado: 19.19% falharam e 80.81% acertaram
#
#
# Com 105 neighbors:
#
# Resultado: 19.62% falharam e 80.38% acertaram
#
#
# Com 115 neighbors:
#
# Resultado: 19.23% falharam e 80.77% acertaram
#
#
# Com 125 neighbors:
#
# Resultado: 19.13% falharam e 80.87% acertaram
#
#
# Com 135 neighbors:
#
# ...

# %%
data = {'5':knn_Acertos_Total[0],
        '15':knn_Acertos_Total[1],
        '25':knn_Acertos_Total[2],
        '35':knn_Acertos_Total[3],
        '45':knn_Acertos_Total[4],
        '55':knn_Acertos_Total[5],
        '65':knn_Acertos_Total[6],
        '75':knn_Acertos_Total[7],
        '85':knn_Acertos_Total[8],
        '95':knn_Acertos_Total[9],
        '105':knn_Acertos_Total[10],
        '115':knn_Acertos_Total[11],
        '125':knn_Acertos_Total[12],
        '135':knn_Acertos_Total[13],
        '145':knn_Acertos_Total[14],
        '155':knn_Acertos_Total[15],
        '165':knn_Acertos_Total[16],
        '175':knn_Acertos_Total[17],
        '185':knn_Acertos_Total[18],
        '195':knn_Acertos_Total[19],
        '205':knn_Acertos_Total[20],
        '215':knn_Acertos_Total[21],
        '225':knn_Acertos_Total[22],
        '235':knn_Acertos_Total[23],
        '245':knn_Acertos_Total[24],
        '255':knn_Acertos_Total[25],
        '265':knn_Acertos_Total[26],
        '275':knn_Acertos_Total[27],
        '285':knn_Acertos_Total[28],
        '295':knn_Acertos_Total[29],
        '305':knn_Acertos_Total[30],
        '315':knn_Acertos_Total[31],
        '325':knn_Acertos_Total[32],
        '335':knn_Acertos_Total[33],
        '345':knn_Acertos_Total[34],
        '355':knn_Acertos_Total[35],
        '365':knn_Acertos_Total[36],
        '375':knn_Acertos_Total[37],
        '385':knn_Acertos_Total[38],
        '395':knn_Acertos_Total[39]}

# Creates pandas DataFrame. 
dfResultados = pd.DataFrame(data, index =['']) 

ax = dfResultados.plot(figsize=(20,15), kind='bar')

# %%
data = {'5':knn_Falhas_Total[0],
        '15':knn_Falhas_Total[1],
        '25':knn_Falhas_Total[2],
        '35':knn_Falhas_Total[3],
        '45':knn_Falhas_Total[4],
        '55':knn_Falhas_Total[5],
        '65':knn_Falhas_Total[6],
        '75':knn_Falhas_Total[7],
        '85':knn_Falhas_Total[8],
        '95':knn_Falhas_Total[9],
        '105':knn_Falhas_Total[10],
        '115':knn_Falhas_Total[11],
        '125':knn_Falhas_Total[12],
        '135':knn_Falhas_Total[13],
        '145':knn_Falhas_Total[14],
        '155':knn_Falhas_Total[15],
        '165':knn_Falhas_Total[16],
        '175':knn_Falhas_Total[17],
        '185':knn_Falhas_Total[18],
        '195':knn_Falhas_Total[19],
        '205':knn_Falhas_Total[20],
        '215':knn_Falhas_Total[21],
        '225':knn_Falhas_Total[22],
        '235':knn_Falhas_Total[23],
        '245':knn_Falhas_Total[24],
        '255':knn_Falhas_Total[25],
        '265':knn_Falhas_Total[26],
        '275':knn_Falhas_Total[27],
        '285':knn_Falhas_Total[28],
        '295':knn_Falhas_Total[29],
        '305':knn_Falhas_Total[30],
        '315':knn_Falhas_Total[31],
        '325':knn_Falhas_Total[32],
        '335':knn_Falhas_Total[33],
        '345':knn_Falhas_Total[34],
        '355':knn_Falhas_Total[35],
        '365':knn_Falhas_Total[36],
        '375':knn_Falhas_Total[37],
        '385':knn_Falhas_Total[38],
        '395':knn_Falhas_Total[39]}

# Creates pandas DataFrame. 
dfResultados = pd.DataFrame(data, index =['']) 

ax = dfResultados.plot(figsize=(20,15), kind='bar')

# %% [markdown]
# # kNN - distance

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

knn_Acertos_Total = np.asarray([])
knn_Falhas_Total = np.asarray([])

X = df.drop('Class', axis=1).values
y = df.Class.values

for x in range(5, 400, 10):
    print("\n\nCom %d neighbors:\n" % (x))

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

    neigh = KNeighborsClassifier(n_neighbors=x, weights='distance')
    #TREINAMENTO
    neigh.fit(X_train, y_train) 

    #TESTE

    Test = neigh.predict(X_test)
    Real = y_test

    KNN_Falhas_distance = round((np.sum(Test != Real)*100)/(Test.size), 2)
    KNN_Acertos_distance = round((np.sum(Test == Real)*100)/(Test.size), 2)
    
    knn_Acertos_Total = np.append(knn_Acertos_Total, KNN_Acertos_distance)
    knn_Falhas_Total = np.append(knn_Falhas_Total, KNN_Falhas_distance)

#     print("%s foram treinados e  %s testes foram feitos. Desses, %s tiveram resultado correto e %s falharam" % (y_train.size, Real.size, np.sum(Test == Real), np.sum(Test != Real)))
    print("Resultado: %s%% falharam e %s%% acertaram" % (KNN_Falhas_distance, KNN_Acertos_distance))
# Out:
# Com 5 neighbors:
#
# Resultado: 21.67% falharam e 78.33% acertaram
#
#
# Com 15 neighbors:
#
# Resultado: 19.13% falharam e 80.87% acertaram
#
#
# Com 25 neighbors:
#
# Resultado: 18.88% falharam e 81.12% acertaram
#
#
# Com 35 neighbors:
#
# Resultado: 18.83% falharam e 81.17% acertaram
#
#
# Com 45 neighbors:
#
# Resultado: 18.54% falharam e 81.46% acertaram
#
#
# Com 55 neighbors:
#
# Resultado: 18.61% falharam e 81.39% acertaram
#
#
# Com 65 neighbors:
#
# Resultado: 18.96% falharam e 81.04% acertaram
#
#
# Com 75 neighbors:
#
# Resultado: 18.7% falharam e 81.3% acertaram
#
#
# Com 85 neighbors:
#
# Resultado: 17.8% falharam e 82.2% acertaram
#
#
# Com 95 neighbors:
#
# Resultado: 18.62% falharam e 81.38% acertaram
#
#
# Com 105 neighbors:
#
# Resultado: 19.02% falharam e 80.98% acertaram
#
#
# Com 115 neighbors:
#
# Resultado: 19.0% falharam e 81.0% acertaram
#
#
# Com 125 neighbors:
#
# Resultado: 19.11% falharam e 80.89% acertaram
#
#
# Com 135 neighbors:
#
# ...

# %%
data = {'5':knn_Acertos_Total[0],
        '15':knn_Acertos_Total[1],
        '25':knn_Acertos_Total[2],
        '35':knn_Acertos_Total[3],
        '45':knn_Acertos_Total[4],
        '55':knn_Acertos_Total[5],
        '65':knn_Acertos_Total[6],
        '75':knn_Acertos_Total[7],
        '85':knn_Acertos_Total[8],
        '95':knn_Acertos_Total[9],
        '105':knn_Acertos_Total[10],
        '115':knn_Acertos_Total[11],
        '125':knn_Acertos_Total[12],
        '135':knn_Acertos_Total[13],
        '145':knn_Acertos_Total[14],
        '155':knn_Acertos_Total[15],
        '165':knn_Acertos_Total[16],
        '175':knn_Acertos_Total[17],
        '185':knn_Acertos_Total[18],
        '195':knn_Acertos_Total[19],
        '205':knn_Acertos_Total[20],
        '215':knn_Acertos_Total[21],
        '225':knn_Acertos_Total[22],
        '235':knn_Acertos_Total[23],
        '245':knn_Acertos_Total[24],
        '255':knn_Acertos_Total[25],
        '265':knn_Acertos_Total[26],
        '275':knn_Acertos_Total[27],
        '285':knn_Acertos_Total[28],
        '295':knn_Acertos_Total[29],
        '305':knn_Acertos_Total[30],
        '315':knn_Acertos_Total[31],
        '325':knn_Acertos_Total[32],
        '335':knn_Acertos_Total[33],
        '345':knn_Acertos_Total[34],
        '355':knn_Acertos_Total[35],
        '365':knn_Acertos_Total[36],
        '375':knn_Acertos_Total[37],
        '385':knn_Acertos_Total[38],
        '395':knn_Acertos_Total[39]}

# Creates pandas DataFrame. 
dfResultados = pd.DataFrame(data, index =['']) 

ax = dfResultados.plot(figsize=(20,15), kind='bar')

# %%
data = {'5':knn_Falhas_Total[0],
        '15':knn_Falhas_Total[1],
        '25':knn_Falhas_Total[2],
        '35':knn_Falhas_Total[3],
        '45':knn_Falhas_Total[4],
        '55':knn_Falhas_Total[5],
        '65':knn_Falhas_Total[6],
        '75':knn_Falhas_Total[7],
        '85':knn_Falhas_Total[8],
        '95':knn_Falhas_Total[9],
        '105':knn_Falhas_Total[10],
        '115':knn_Falhas_Total[11],
        '125':knn_Falhas_Total[12],
        '135':knn_Falhas_Total[13],
        '145':knn_Falhas_Total[14],
        '155':knn_Falhas_Total[15],
        '165':knn_Falhas_Total[16],
        '175':knn_Falhas_Total[17],
        '185':knn_Falhas_Total[18],
        '195':knn_Falhas_Total[19],
        '205':knn_Falhas_Total[20],
        '215':knn_Falhas_Total[21],
        '225':knn_Falhas_Total[22],
        '235':knn_Falhas_Total[23],
        '245':knn_Falhas_Total[24],
        '255':knn_Falhas_Total[25],
        '265':knn_Falhas_Total[26],
        '275':knn_Falhas_Total[27],
        '285':knn_Falhas_Total[28],
        '295':knn_Falhas_Total[29],
        '305':knn_Falhas_Total[30],
        '315':knn_Falhas_Total[31],
        '325':knn_Falhas_Total[32],
        '335':knn_Falhas_Total[33],
        '345':knn_Falhas_Total[34],
        '355':knn_Falhas_Total[35],
        '365':knn_Falhas_Total[36],
        '375':knn_Falhas_Total[37],
        '385':knn_Falhas_Total[38],
        '395':knn_Falhas_Total[39]}

# Creates pandas DataFrame. 
dfResultados = pd.DataFrame(data, index =['']) 

ax = dfResultados.plot(figsize=(20,15), kind='bar')
