# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn import preprocessing

import tensorflow as tf
from keras import models
from keras import layers

import math
from sklearn.model_selection import train_test_split, StratifiedKFold
import keras
from keras.models import Sequential, Model
from keras.layers import Input, Flatten, Dense, Dropout, Convolution2D, Conv2D, MaxPooling2D, Lambda, GlobalMaxPooling2D, GlobalAveragePooling2D, BatchNormalization, Activation, AveragePooling2D, Concatenate
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.utils import np_utils

from IPython.display import Image
from IPython.core.display import HTML 

# %matplotlib inline
keras.backend.set_image_data_format('channels_last')

# %%
df = pd.read_csv("credit_preprocessed.csv")

# %%
df.shape
df = df.drop('ID', axis=1)

# %% [markdown]
# # RandomForest - n_estimators

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

def load_data_kfold(k):
    
    train = df
    
    X_train = np.array(df.drop('Class', axis=1).values)
    
    y_train = np.array(train["Class"].values)
    
    folds = list(StratifiedKFold(n_splits=k, shuffle=True, random_state=1).split(X_train, y_train))
    
    return folds, X_train, y_train


RForest_Acertos_Total = np.asarray([])
RForest_Falhas_Total = np.asarray([])

for x in range(5, 400, 30):
    print("\n\nCom %d estimators:\n" % (x))
    
    RForest_Falhas_Media = 0
    RForest_Acertos_Media = 0

    X = np.array(df.drop('Class', axis=1).values)
    y = np.array(df.Class.values)

    rf = RandomForestClassifier(n_estimators = x)

    k = 7
    folds, X_train, y_train = load_data_kfold(k)


    for j, (train_idx, val_idx) in enumerate(folds):

        print('\nFold ',j)
        X_train_cv = X_train[train_idx]
        y_train_cv = y_train[train_idx]
        X_valid_cv = X_train[val_idx]
        y_valid_cv = y_train[val_idx]

        rf.fit(X_train_cv,
               y_train_cv) 

        Test = rf.predict(X_valid_cv)
        Real = y_valid_cv

        RForest_Falhas = round((np.sum(Test != Real)*100)/(Test.size), 2)
        RForest_Acertos = round((np.sum(Test == Real)*100)/(Test.size), 2)

        RForest_Falhas_Media = (RForest_Falhas_Media + RForest_Falhas)
        RForest_Acertos_Media = (RForest_Acertos_Media + RForest_Acertos)

        print("Resultado: %s falharam e %s acertaram" % (RForest_Falhas, RForest_Acertos))

    RForest_Falhas_Media = RForest_Falhas_Media/k
    RForest_Acertos_Media = RForest_Acertos_Media/k

    print("\nResultado Final (Média dos %s folds): %.2f falharam e %.2f acertaram" % (k, RForest_Falhas_Media, RForest_Acertos_Media))
    RForest_Acertos_Total = np.append(RForest_Acertos_Total, RForest_Acertos_Media)
    RForest_Falhas_Total = np.append(RForest_Falhas_Total, RForest_Falhas_Media)
# Out:
# Com 5 estimators:
#
#
# Fold  0
# Resultado: 21.35 falharam e 78.65 acertaram
#
# Fold  1
# Resultado: 21.75 falharam e 78.25 acertaram
#
# Fold  2
# Resultado: 21.56 falharam e 78.44 acertaram
#
# Fold  3
# Resultado: 21.49 falharam e 78.51 acertaram
#
# Fold  4
# Resultado: 21.23 falharam e 78.77 acertaram
#
# Fold  5
# Resultado: 21.19 falharam e 78.81 acertaram
#
# Fold  6
# Resultado: 21.49 falharam e 78.51 acertaram
#
# Resultado Final (Média dos 7 folds): 21.44 falharam e 78.56 acertaram
#
#
# Com 35 estimators:
#
#
# Fold  0
# Resultado: 18.53 falharam e 81.47 acertaram
#
# Fold  1
# Resultado: 18.48 falharam e 81.52 acertaram
#
# Fold  2
# Resultado: 18.46 falharam e 81.54 acertaram
#
# Fold  3
# Resultado: 18.57 falharam e 81.43 acertaram
#
# Fold  4
# Resultado: 17.9 falharam e 82.1 acertaram
#
# Fold  5
# Resultado: 18.65 falharam e 81.35 acertaram
#
# Fold  6
# Resultado: 19.09 falharam e 80.91 acertaram
#
# Resultado Final (Média dos 7 folds): 18.53 falharam e 81.47 acertaram
#
#
# Com 65 estimators:
#
#
# Fold  0
# Resultado: 18.5 falharam e 81.5 acertaram
#
# Fold  1
# Resultado: 18.2 falharam e 81.8 acertaram
#
# Fold  2
# Resultado: 18.57 falharam e 81.43 acertaram
#
# Fold  3
# Resultado: 18.46 falharam e 81.54 acertaram
#
# Fold  4
# Resultado: 17.92 falharam e 82.08 acertaram
#
# Fold  5
# Resultado: 18.27 falharam e 81.73 acertaram
#
# Fold  6
# Resultado: 18.48 falharam e 81.52 acertaram
#
# Resultado Final (Média dos 7 folds): 18.34 falharam e 81.66 acertaram
#
#
# Com 95 estimators:
#
#
# Fold  0
# Resultado: 18.6 falharam e 81.4 acertaram
#
# Fold  1
# Resultado: 18.43 falharam e 81.57 acertaram
#
# Fold  2
# Resultado: 18.34 falharam e 81.66 acertaram
#
# Fold  3
# Resultado: 18.81 falharam e 81.19 acertaram
#
# Fold  4
# Resultado: 18.15 falharam e 81.85 acertaram
#
# Fold  5
# Resultado: 18.39 falharam e 81.61 acertaram
#
# Fold  6
# Resultado: 18.74 falharam e 81.26 acertaram
#
# Resultado Final (Média dos 7 folds): 18.49 falharam e 81.51 acertaram
#
#
# Com 125 estimators:
#
#
# Fold  0
# Resultado: 18.36 falharam e 81.64 acertaram
#
# Fold  1
# Resultado: 17.99 falharam e 82.01 acertaram
#
# Fold  2
# Resultado: 18.34 falharam e 81.66 acertaram
#
# Fold  3
# Resultado: 18.39 falharam e 81.61 acertaram
#
# Fold  4
# Resultado: 18.08 falharam e 81.92 acertaram
#
# Fold  5
# Resultado: 18.39 falharam e 81.61 acertaram
#
# Fold  6
# Resultado: 18.48 falharam e 81.52 acertaram
#
# Resultado Final (Média dos 7 folds): 18.29 falharam e 81.71 acertaram
#
#
# Com 155 estimators:
#
#
# Fold  0
# Resultado: 18.29 falharam e 81.71 acertaram
#
# Fold  1
# Resultado: 17.99 falharam e 82.01 acertaram
#
# Fold  2
# Resultado: 17.92 falharam e 82.08 acertaram
#
# Fold  3
# Resultado: 18.39 falharam e 81.61 acertaram
#
# Fold  4
# Resultado: 17.71 falharam e 82.29 acertaram
#
# Fold  5
# Resultado: 18.16 falharam e 81.84 acertaram
#
# Fold  6
# Resultado: 18.51 falharam e 81.49 acertaram
#
# Resultado Final (Média dos 7 folds): 18.14 falharam e 81.86 acertaram
#
#
# Com 185 estimators:
#
#
# Fold  0
# Resultado: 18.55 falharam e 81.45 acertaram
#
# Fold  1
# Resultado: 18.29 falharam e 81.71 acertaram
#
# Fold  2
# Resultado: 18.01 falharam e 81.99 acertaram
#
# Fold  3
# Resultado: 18.55 falharam e 81.45 acertaram
#
# Fold  4
# Resultado: 18.11 falharam e 81.89 acertaram
#
# Fold  5
# Resultado: 18.32 falharam e 81.68 acertaram
#
# Fold  6
# Resultado: 18.67 falharam e 81.33 acertaram
#
# Resultado Final (Média dos 7 folds): 18.36 falharam e 81.64 acertaram
#
#
# Com 215 estimators:
#
#
# Fold  0
# Resultado: 18.46 falharam e 81.54 acertaram
#
# Fold  1
# Resultado: 18.29 falharam e 81.71 acertaram
#
# Fold  2
# Resultado: 18.22 falharam e 81.78 acertaram
#
# Fold  3
# Resultado: 18.53 falharam e 81.47 acertaram
#
# Fold  4
# Resultado: 18.13 falharam e 81.87 acertaram
#
# Fold  5
# Resultado: 18.13 falharam e 81.87 acertaram
#
# Fold  6
# Resultado: 18.62 falharam e 81.38 acertaram
#
# Resultado Final (Média dos 7 folds): 18.34 falharam e 81.66 acertaram
#
#
# Com 245 estimators:
#
#
# Fold  0
# Resultado: 18.18 falharam e 81.82 acertaram
#
# Fold  1
# Resultado: 18.41 falharam e 81.59 acertaram
#
# Fold  2
# Resultado: 18.08 falharam e 81.92 acertaram
#
# Fold  3
# Resultado: 18.22 falharam e 81.78 acertaram
#
# Fold  4
# Resultado: 18.08 falharam e 81.92 acertaram
#
# Fold  5
# Resultado: 18.23 falharam e 81.77 acertaram
#
# Fold  6
# Resultado: 18.53 falharam e 81.47 acertaram
#
# Resultado Final (Média dos 7 folds): 18.25 falharam e 81.75 acertaram
#
#
# Com 275 estimators:
#
#
# Fold  0
# Resultado: 18.34 falharam e 81.66 acertaram
#
# Fold  1
# Resultado: 18.27 falharam e 81.73 acertaram
#
# Fold  2
# Resultado: 18.36 falharam e 81.64 acertaram
#
# Fold  3
# Resultado: 18.46 falharam e 81.54 acertaram
#
# Fold  4
# Resultado: 18.13 falharam e 81.87 acertaram
#
# Fold  5
# Resultado: 18.3 falharam e 81.7 acertaram
#
# Fold  6
# Resultado: 18.46 falharam e 81.54 acertaram
#
# Resultado Final (Média dos 7 folds): 18.33 falharam e 81.67 acertaram
#
#
# Com 305 estimators:
#
#
# Fold  0
# Resultado: 18.29 falharam e 81.71 acertaram
#
# Fold  1
# Resultado: 18.41 falharam e 81.59 acertaram
#
# Fold  2
# Resultado: 18.62 falharam e 81.38 acertaram
#
# Fold  3
# Resultado: 18.41 falharam e 81.59 acertaram
#
# Fold  4
# Resultado: 17.87 falharam e 82.13 acertaram
#
# Fold  5
# Resultado: 18.13 falharam e 81.87 acertaram
#
# Fold  6
# Resultado: 18.46 falharam e 81.54 acertaram
#
# Resultado Final (Média dos 7 folds): 18.31 falharam e 81.69 acertaram
#
#
# Com 335 estimators:
#
#
# Fold  0
# Resultado: 18.43 falharam e 81.57 acertaram
#
# Fold  1
# Resultado: 18.25 falharam e 81.75 acertaram
#
# Fold  2
# Resultado: 18.29 falharam e 81.71 acertaram
#
# Fold  3
# Resultado: 18.27 falharam e 81.73 acertaram
#
# Fold  4
# Resultado: 18.13 falharam e 81.87 acertaram
#
# Fold  5
# Resultado: 18.18 falharam e 81.82 acertaram
#
# Fold  6
# Resultado: 18.46 falharam e 81.54 acertaram
#
# Resultado Final (Média dos 7 folds): 18.29 falharam e 81.71 acertaram
#
#
# Com 365 estimators:
#
#
# Fold  0
# Resultado: 18.43 falharam e 81.57 acertaram
#
# Fold  1
# Resultado: 18.36 falharam e 81.64 acertaram
#
# Fold  2
# Resultado: 18.15 falharam e 81.85 acertaram
#
# Fold  3
# Resultado: 18.62 falharam e 81.38 acertaram
#
# Fold  4
# Resultado: 18.01 falharam e 81.99 acertaram
#
# Fold  5
# Resultado: 18.18 falharam e 81.82 acertaram
#
# Fold  6
# Resultado: 18.46 falharam e 81.54 acertaram
#
# Resultado Final (Média dos 7 folds): 18.32 falharam e 81.68 acertaram
#
#
# Com 395 estimators:
#
#
# Fold  0
# Resultado: 18.36 falharam e 81.64 acertaram
#
# Fold  1
# Resultado: 18.34 falharam e 81.66 acertaram
#
# Fold  2
# Resultado: 18.25 falharam e 81.75 acertaram
#
# Fold  3
# Resultado: 18.32 falharam e 81.68 acertaram
#
# Fold  4
# Resultado: 18.43 falharam e 81.57 acertaram
#
# Fold  5
# Resultado: 18.18 falharam e 81.82 acertaram
#
# Fold  6
# Resultado: 18.51 falharam e 81.49 acertaram
#
# Resultado Final (Média dos 7 folds): 18.34 falharam e 81.66 acertaram

# %%
data = {'5':RForest_Acertos_Total[0],
        '35':RForest_Acertos_Total[1],
        '65':RForest_Acertos_Total[2],
        '95':RForest_Acertos_Total[3],
        '125':RForest_Acertos_Total[4],
        '155':RForest_Acertos_Total[5],
        '185':RForest_Acertos_Total[6],
        '215':RForest_Acertos_Total[7],
        '245':RForest_Acertos_Total[8],
        '275':RForest_Acertos_Total[9],
        '305':RForest_Acertos_Total[10],
        '335':RForest_Acertos_Total[11],
        '365':RForest_Acertos_Total[12],
        '395':RForest_Acertos_Total[13]}

# Creates pandas DataFrame. 
dfResultados = pd.DataFrame(data, index =['Acertos para cada estimator']) 
plt.rcParams['figure.figsize'] = [10, 10]
ax = dfResultados.plot.bar(rot=0)
ax.set_ylim(79, 82)
# Out:
# (79, 82)

# %%
data = {'5':RForest_Falhas_Total[0],
        '35':RForest_Falhas_Total[1],
        '65':RForest_Falhas_Total[2],
        '95':RForest_Falhas_Total[3],
        '125':RForest_Falhas_Total[4],
        '155':RForest_Falhas_Total[5],
        '185':RForest_Falhas_Total[6],
        '215':RForest_Falhas_Total[7],
        '245':RForest_Falhas_Total[8],
        '275':RForest_Falhas_Total[9],
        '305':RForest_Falhas_Total[10],
        '335':RForest_Falhas_Total[11],
        '365':RForest_Falhas_Total[12],
        '395':RForest_Falhas_Total[13]}

# Creates pandas DataFrame. 
dfResultados = pd.DataFrame(data, index =['Falhas para cada estimator']) 

plt.rcParams['figure.figsize'] = [10, 10]
ax = dfResultados.plot.bar(rot=0)
ax.set_ylim(18, 21)
# Out:
# (18, 21)

# %% [markdown]
# # RandomForest - max_leaf_nodes

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

def load_data_kfold(k):
    
    train = df
    
    X_train = np.array(df.drop('Class', axis=1).values)
    
    y_train = np.array(train["Class"].values)
    
    folds = list(StratifiedKFold(n_splits=k, shuffle=True, random_state=1).split(X_train, y_train))
    
    return folds, X_train, y_train


RForest_Acertos_Total = np.asarray([])
RForest_Falhas_Total = np.asarray([])

for x in range(5, 400, 30):
    print("\n\nCom no máximo %d leafs :\n" % (x))
    
    RForest_Falhas_Media = 0
    RForest_Acertos_Media = 0

    X = np.array(df.drop('Class', axis=1).values)
    y = np.array(df.Class.values)

    rf = RandomForestClassifier(n_estimators = 200, max_leaf_nodes= x)

    k = 2
    folds, X_train, y_train = load_data_kfold(k)


    for j, (train_idx, val_idx) in enumerate(folds):

        print('\nFold ',j)
        X_train_cv = X_train[train_idx]
        y_train_cv = y_train[train_idx]
        X_valid_cv = X_train[val_idx]
        y_valid_cv = y_train[val_idx]

        rf.fit(X_train_cv,
               y_train_cv) 

        Test = rf.predict(X_valid_cv)
        Real = y_valid_cv

        RForest_Falhas = round((np.sum(Test != Real)*100)/(Test.size), 2)
        RForest_Acertos = round((np.sum(Test == Real)*100)/(Test.size), 2)

        RForest_Falhas_Media = (RForest_Falhas_Media + RForest_Falhas)
        RForest_Acertos_Media = (RForest_Acertos_Media + RForest_Acertos)

        print("Resultado: %s falharam e %s acertaram" % (RForest_Falhas, RForest_Acertos))

    RForest_Falhas_Media = RForest_Falhas_Media/k
    RForest_Acertos_Media = RForest_Acertos_Media/k

    print("\nResultado Final (Média dos %s folds): %.2f falharam e %.2f acertaram" % (k, RForest_Falhas_Media, RForest_Acertos_Media))
    RForest_Acertos_Total = np.append(RForest_Acertos_Total, RForest_Acertos_Media)
    RForest_Falhas_Total = np.append(RForest_Falhas_Total, RForest_Falhas_Media)
# Out:
# Com no máximo 5 leafs :
#
#
# Fold  0
# Resultado: 20.65 falharam e 79.35 acertaram
#
# Fold  1
# Resultado: 20.55 falharam e 79.45 acertaram
#
# Resultado Final (Média dos 2 folds): 20.60 falharam e 79.40 acertaram
#
#
# Com no máximo 35 leafs :
#
#
# Fold  0
# Resultado: 18.94 falharam e 81.06 acertaram
#
# Fold  1
# Resultado: 18.81 falharam e 81.19 acertaram
#
# Resultado Final (Média dos 2 folds): 18.88 falharam e 81.12 acertaram
#
#
# Com no máximo 65 leafs :
#
#
# Fold  0
# Resultado: 18.54 falharam e 81.46 acertaram
#
# Fold  1
# Resultado: 18.46 falharam e 81.54 acertaram
#
# Resultado Final (Média dos 2 folds): 18.50 falharam e 81.50 acertaram
#
#
# Com no máximo 95 leafs :
#
#
# Fold  0
# Resultado: 18.55 falharam e 81.45 acertaram
#
# Fold  1
# Resultado: 18.37 falharam e 81.63 acertaram
#
# Resultado Final (Média dos 2 folds): 18.46 falharam e 81.54 acertaram
#
#
# Com no máximo 125 leafs :
#
#
# Fold  0
# Resultado: 18.62 falharam e 81.38 acertaram
#
# Fold  1
# Resultado: 18.23 falharam e 81.77 acertaram
#
# Resultado Final (Média dos 2 folds): 18.43 falharam e 81.57 acertaram
#
#
# Com no máximo 155 leafs :
#
#
# Fold  0
# Resultado: 18.31 falharam e 81.69 acertaram
#
# Fold  1
# Resultado: 18.25 falharam e 81.75 acertaram
#
# Resultado Final (Média dos 2 folds): 18.28 falharam e 81.72 acertaram
#
#
# Com no máximo 185 leafs :
#
#
# Fold  0
# Resultado: 18.37 falharam e 81.63 acertaram
#
# Fold  1
# Resultado: 18.22 falharam e 81.78 acertaram
#
# Resultado Final (Média dos 2 folds): 18.30 falharam e 81.70 acertaram
#
#
# Com no máximo 215 leafs :
#
#
# Fold  0
# Resultado: 18.27 falharam e 81.73 acertaram
#
# Fold  1
# Resultado: 18.33 falharam e 81.67 acertaram
#
# Resultado Final (Média dos 2 folds): 18.30 falharam e 81.70 acertaram
#
#
# Com no máximo 245 leafs :
#
#
# Fold  0
# Resultado: 18.23 falharam e 81.77 acertaram
#
# Fold  1
# Resultado: 18.22 falharam e 81.78 acertaram
#
# Resultado Final (Média dos 2 folds): 18.23 falharam e 81.78 acertaram
#
#
# Com no máximo 275 leafs :
#
#
# Fold  0
# Resultado: 18.28 falharam e 81.72 acertaram
#
# Fold  1
# Resultado: 18.25 falharam e 81.75 acertaram
#
# Resultado Final (Média dos 2 folds): 18.27 falharam e 81.73 acertaram
#
#
# Com no máximo 305 leafs :
#
#
# Fold  0
# Resultado: 18.08 falharam e 81.92 acertaram
#
# Fold  1
# Resultado: 18.25 falharam e 81.75 acertaram
#
# Resultado Final (Média dos 2 folds): 18.16 falharam e 81.84 acertaram
#
#
# Com no máximo 335 leafs :
#
#
# Fold  0
# Resultado: 18.26 falharam e 81.74 acertaram
#
# Fold  1
# Resultado: 18.22 falharam e 81.78 acertaram
#
# Resultado Final (Média dos 2 folds): 18.24 falharam e 81.76 acertaram
#
#
# Com no máximo 365 leafs :
#
#
# Fold  0
# Resultado: 18.27 falharam e 81.73 acertaram
#
# Fold  1
# Resultado: 18.43 falharam e 81.57 acertaram
#
# Resultado Final (Média dos 2 folds): 18.35 falharam e 81.65 acertaram
#
#
# Com no máximo 395 leafs :
#
#
# Fold  0
# Resultado: 18.25 falharam e 81.75 acertaram
#
# Fold  1
# Resultado: 18.3 falharam e 81.7 acertaram
#
# Resultado Final (Média dos 2 folds): 18.27 falharam e 81.72 acertaram

# %%
data = {'5':RForest_Acertos_Total[0],
        '35':RForest_Acertos_Total[1],
        '65':RForest_Acertos_Total[2],
        '95':RForest_Acertos_Total[3],
        '125':RForest_Acertos_Total[4],
        '155':RForest_Acertos_Total[5],
        '185':RForest_Acertos_Total[6],
        '215':RForest_Acertos_Total[7],
        '245':RForest_Acertos_Total[8],
        '275':RForest_Acertos_Total[9],
        '305':RForest_Acertos_Total[10],
        '335':RForest_Acertos_Total[11],
        '365':RForest_Acertos_Total[12],
        '395':RForest_Acertos_Total[13]}

# Creates pandas DataFrame. 
dfResultados = pd.DataFrame(data, index =['Acertos para cada valor máximo de folhas']) 

plt.rcParams['figure.figsize'] = [10, 10]
ax = dfResultados.plot.bar(rot=0)
ax.set_ylim(79, 82)
# Out:
# (79, 82)

# %%
data = {'5':RForest_Falhas_Total[0],
        '35':RForest_Falhas_Total[1],
        '65':RForest_Falhas_Total[2],
        '95':RForest_Falhas_Total[3],
        '125':RForest_Falhas_Total[4],
        '155':RForest_Falhas_Total[5],
        '185':RForest_Falhas_Total[6],
        '215':RForest_Falhas_Total[7],
        '245':RForest_Falhas_Total[8],
        '275':RForest_Falhas_Total[9],
        '305':RForest_Falhas_Total[10],
        '335':RForest_Falhas_Total[11],
        '365':RForest_Falhas_Total[12],
        '395':RForest_Falhas_Total[13]}

# Creates pandas DataFrame. 
dfResultados = pd.DataFrame(data, index =['Falhas para cada valor máximo de folhas']) 

plt.rcParams['figure.figsize'] = [10, 10]
ax = dfResultados.plot.bar(rot=0)
ax.set_ylim(18, 21)
# Out:
# (18, 21)
